# %%
print("trabajo final")
# Out:
# trabajo final

# %%
print("integrantes : Waldo,Valentina,Dhomeli,Danixa,Juan,Armando")
# Out:
# integrantes : Waldo,Valentina,Dhomeli,Danixa,Juan,Armando

# %%
print("PRESENTACIÓN")
# Out:
# PRESENTACIÓN

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sb
import csv

# %%
##Leyendo un archivo
import pandas as pd
import csv
df = pd.read_csv("encuestaep.csv",encoding='latin1') # latin1 nos permite trabajar con tildes
df
# Out:
#     usuario categoria satisfaccion
# 0         1         A      regular
# 1         2         E         malo
# 2         3         D      regular
# 3         4         D      regular
# 4         5         B      regular
# 5         6         C      regular
# 6         7         D         malo
# 7         8         B      regular
# 8         9         B      regular
# 9        10         D      regular
# 10       11         D      regular
# 11       12         C         malo
# 12       13         E        buena
# 13       14         A         malo
# 14       15         C      regular
# 15       16         C        buena
# 16       17         D      regular
# 17       18         D         malo
# 18       19         C      regular
# 19       20         C        buena
# 20       21         C        buena

# %%
tabla = pd.crosstab(index=df['satisfaccion'],
            columns=df['categoria'], margins=True)

# %%
tabla
# Out:
# categoria     A  B  C  D  E  All
# satisfaccion
# buena         0  0  3  0  1    4
# malo          1  0  1  2  1    5
# regular       1  3  3  5  0   12
# All           2  3  7  7  2   21

# %%
for i in range(2):
    for j in range(2):
        print(tabla.iloc[i,j])
# Out:
# 3
# 5
# 1
# 1

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
pd.crosstab(index=df['satisfaccion'], columns=df['categoria'],
            margins=True).apply(lambda r: r/len(df) *100,
                                axis=1)
# Out:
# categoria            A          B          C          D         E         All
# satisfaccion
# buena         0.000000   0.000000  14.285714   0.000000  4.761905   19.047619
# malo          4.761905   0.000000   4.761905   9.523810  4.761905   23.809524
# regular       4.761905  14.285714  14.285714  23.809524  0.000000   57.142857
# All           9.523810  14.285714  33.333333  33.333333  9.523810  100.000000

# %%
# Gráfico de barras 
plot = pd.crosstab(index=df['satisfaccion'],
            columns=df['categoria']).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar')

# %% [markdown]
# ## PANDAS Y ESTADISTICO GAMMA
# Tomando como referencia una data pequeña sobre estrato vs opinión

# %%
import pandas as pd
data = pd.read_csv("encuestaep.csv",encoding='latin1')

# %%
data
# Out:
#     usuario categoria satisfaccion
# 0         1         A      regular
# 1         2         E         malo
# 2         3         D      regular
# 3         4         D      regular
# 4         5         B      regular
# 5         6         C      regular
# 6         7         D         malo
# 7         8         B      regular
# 8         9         B      regular
# 9        10         D      regular
# 10       11         D      regular
# 11       12         C         malo
# 12       13         E        buena
# 13       14         A         malo
# 14       15         C      regular
# 15       16         C        buena
# 16       17         D      regular
# 17       18         D         malo
# 18       19         C      regular
# 19       20         C        buena
# 20       21         C        buena

# %% [markdown]
# Acomodadndo en una tabla de doble entrada
#
# El margins es para colocar el total , suma filas , suma columnas

# %%
tabla_p = pd.crosstab(index=data['satisfaccion'],
            columns=data['categoria'], margins=True)
tabla_p
# Out:
# categoria     A  B  C  D  E  All
# satisfaccion
# buena         0  0  3  0  1    4
# malo          1  0  1  2  1    5
# regular       1  3  3  5  0   12
# All           2  3  7  7  2   21

# %%
# CANTIDAD DE INDEX Y COLUMNS EN UNA TABLA
# ESTRATO             OPINIÓN
f = list(tabla_p.columns)
g = tabla_p.index

print(g)
print(len(g)-1)

print(f)
print(len(f)-1)
# Out:
# Index(['buena', 'malo', 'regular', 'All'], dtype='object', name='satisfaccion')
# 3
# ['A', 'B', 'C', 'D', 'E', 'All']
# 5

# %%
class EstaGamma:
    
    def __init__(self):
        pass
    
    def __str__(self):
        return("Ingresar en el metodo concordantes y discordantes (g,f) las filas en g y las columnas en f ,Para hallar el estadistico gamma ingrese gamma() sin ningun atributo")
    
    def concordantes(self,g,f):
        global c
        c=0
        k = list(range(len(g)-1)) # SI SE GENERALIZA DE ALGUNA FORMA MEJOR
        l = list(range(len(f)-1))  
        for i in range(len(g)-1): # filas --> 4
            for j in range(len(f)-1): # columnas --> 3
                s = 0
                print("------------------------------------")
                print("Estamos en el par (",i,",",j ,")y el valor de este es :",tabla_p.iloc[i,j])
                elemento = tabla_p.iloc[i,j]
                for x in k :
                    for y in l :
                        if  x > i:
                            if y > j :
                                print("El par ",(x,y)," es :",tabla_p.iloc[x,y])
                                s = s + tabla_p.iloc[x,y]
                print("La Suma es de todos los pares hallados es ",s)
                print("El Producto seria ",s,"con ",elemento,"que resulta ->",s*elemento)
                c = c + elemento*s
         
        
        print("EL TOTAL DE CONCORDANTES ES" ,c)
        
    def discordantes(self,g,f):
        global d
        d = 0
        k = list(range(len(g)-1)) ##SI SE GENERALIZA DE ALGUNA FORMA MEJOR
        l = list(range(len(f)-1))
        for i in range(len(g)-1): # filas --> 4
            for j in range(len(f)-1): # columnas --> 3
                s = 0
                print("--------------------------------------")
                print("Estamos en el par (",i,",",j,")y el valor de este es :",tabla_p.iloc[i,j])
                elemento = tabla_p.iloc[i,j]
                for x in k :
                    for y in l :
                        if  x > i:
                            if y < j :
                                print("El par ",(x,y)," es :",tabla_p.iloc[x,y])
                                s = s + tabla_p.iloc[x,y]
                print("La Suma es ",s)
                print("El Producto seria ",s,"con ",elemento,"que resulta ->",s*elemento)
                d = d + elemento*s
                
       
        print("EL TOTAL DE CONCORDANTES ES" ,d)
    
    def gamma(self):
        eg = (c-d)/(c+d)
        print("EL ESTADISTICO GAMMA PARA LA TABLA PROPUESTA ES",eg)

# %%
Ola= EstaGamma()
print(Ola)
Ola.concordantes(g,f)
#Ola.discordantes(g,f)
#Ola.gamma()
# Out:
# Ingresar en el metodo concordantes y discordantes (g,f) las filas en g y las columnas en f ,Para hallar el estadistico gamma ingrese gamma() sin ningun atributo
# ------------------------------------
# Estamos en el par ( 0 , 0 )y el valor de este es : 0
# El par  (1, 1)  es : 0
# El par  (1, 2)  es : 1
# El par  (1, 3)  es : 2
# El par  (1, 4)  es : 1
# El par  (2, 1)  es : 3
# El par  (2, 2)  es : 3
# El par  (2, 3)  es : 5
# El par  (2, 4)  es : 0
# La Suma es de todos los pares hallados es  15
# El Producto seria  15 con  0 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 0 , 1 )y el valor de este es : 0
# El par  (1, 2)  es : 1
# El par  (1, 3)  es : 2
# El par  (1, 4)  es : 1
# El par  (2, 2)  es : 3
# El par  (2, 3)  es : 5
# El par  (2, 4)  es : 0
# La Suma es de todos los pares hallados es  12
# El Producto seria  12 con  0 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 0 , 2 )y el valor de este es : 3
# El par  (1, 3)  es : 2
# El par  (1, 4)  es : 1
# El par  (2, 3)  es : 5
# El par  (2, 4)  es : 0
# La Suma es de todos los pares hallados es  8
# El Producto seria  8 con  3 que resulta -> 24
# ------------------------------------
# Estamos en el par ( 0 , 3 )y el valor de este es : 0
# El par  (1, 4)  es : 1
# El par  (2, 4)  es : 0
# La Suma es de todos los pares hallados es  1
# El Producto seria  1 con  0 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 0 , 4 )y el valor de este es : 1
# La Suma es de todos los pares hallados es  0
# El Producto seria  0 con  1 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 1 , 0 )y el valor de este es : 1
# El par  (2, 1)  es : 3
# El par  (2, 2)  es : 3
# El par  (2, 3)  es : 5
# El par  (2, 4)  es : 0
# La Suma es de todos los pares hallados es  11
# El Producto seria  11 con  1 que resulta -> 11
# ------------------------------------
# Estamos en el par ( 1 , 1 )y el valor de este es : 0
# El par  (2, 2)  es : 3
# El par  (2, 3)  es : 5
# El par  (2, 4)  es : 0
# La Suma es de todos los pares hallados es  8
# El Producto seria  8 con  0 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 1 , 2 )y el valor de este es : 1
# El par  (2, 3)  es : 5
# El par  (2, 4)  es : 0
# La Suma es de todos los pares hallados es  5
# El Producto seria  5 con  1 que resulta -> 5
# ------------------------------------
# Estamos en el par ( 1 , 3 )y el valor de este es : 2
# El par  (2, 4)  es : 0
# La Suma es de todos los pares hallados es  0
# El Producto seria  0 con  2 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 1 , 4 )y el valor de este es : 1
# La Suma es de todos los pares hallados es  0
# El Producto seria  0 con  1 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 2 , 0 )y el valor de este es : 1
# La Suma es de todos los pares hallados es  0
# El Producto seria  0 con  1 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 2 , 1 )y el valor de este es : 3
# La Suma es de todos los pares hallados es  0
# El Producto seria  0 con  3 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 2 , 2 )y el valor de este es : 3
# La Suma es de todos los pares hallados es  0
# El Producto seria  0 con  3 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 2 , 3 )y el valor de este es : 5
# La Suma es de todos los pares hallados es  0
# El Producto seria  0 con  5 que resulta -> 0
# ------------------------------------
# Estamos en el par ( 2 , 4 )y el valor de este es : 0
# La Suma es de todos los pares hallados es  0
# El Producto seria  0 con  0 que resulta -> 0
# EL TOTAL DE CONCORDANTES ES 40
